# %%
import pandas as pd
import glob
import xml.etree.ElementTree as ET
import csv
import re

# %%
pd.read_xml("0000-0001-5001-0010_works_90273982.xml")
# Out:
#                 created-date        last-modified-date  source-client-id  \
# 0   2021-03-09T14:27:11.442Z                      None               NaN
# 1                       None  2021-03-09T14:27:11.442Z               NaN
# 2                       None                      None               NaN
# 3                       None                      None               NaN
# 4                       None                      None               NaN
# 5                       None                      None               NaN
# 6                       None                      None               NaN
# 7                       None                      None               NaN
# 8                       None                      None               NaN
# 9                       None                      None               NaN
# 10                      None                      None               NaN
#
#           source-name  assertion-origin-orcid assertion-origin-name  \
# ...
